# %% [markdown]
# <a href="https://colab.research.google.com/github/KorKanticha/SeniorProject/blob/main/Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Correlation

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from google.colab import drive
drive.mount('/content/gdrive')

xls_Suicide = pd.ExcelFile("/content/gdrive/MyDrive/SeniorProject_KorBoss/We_will_SURVIVE.xlsx")
df = dict()
df = pd.read_excel(xls_Suicide)

xls_Suicide2 = pd.ExcelFile("/content/gdrive/MyDrive/SeniorProject_KorBoss/Cleaned_Dummy9.xlsx")
df2 = dict()
df2 = pd.read_excel(xls_Suicide2)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #We_will_SURVIVE

# %%
df = pd.read_excel(xls_Suicide)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cb1c8480995e> in <module>()
# ----> 1 df = pd.read_excel(xls_Suicide)
#       2 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     393             skipfooter=skipfooter,
#     394             convert_float=convert_float,
# --> 395             mangle_dupe_cols=mangle_dupe_cols,
#     396         )
#     397     finally:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1290             convert_float=convert_float,
#    1291             mangle_dupe_cols=mangle_dupe_cols,
# -> 1292             **kwds,
#    1293         )
#    1294
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     537                 sheet = self.get_sheet_by_index(asheetname)
#     538
# --> 539             data = self.get_sheet_data(sheet, convert_float)
#     540             if hasattr(sheet, "close"):
#     541                 # pyxlsb opens two TemporaryFiles
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_openpyxl.py in get_sheet_data(self, sheet, convert_float)
#     570         data: list[list[Scalar]] = []
#     571         last_row_with_data = -1
# --> 572         for row_number, row in enumerate(sheet.rows):
#     573             converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     574             while converted_row and converted_row[-1] == "":
#
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_read_only.py in _cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77                                  data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                                  date_formats=self.parent._date_formats)
# ---> 79         for idx, row in parser.parse():
#      80             if max_row is not None and idx > max_row:
#      81                 break
#
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py in parse(self)
#     142         it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
#     143
# --> 144         for _, element in it:
#     145             tag_name = element.tag
#     146             if tag_name in dispatcher:
#
# /usr/lib/python3.7/xml/etree/ElementTree.py in iterator()
#    1225                 if not data:
#    1226                     break
# -> 1227                 pullparser.feed(data)
#    1228             root = pullparser._close_and_return_root()
#    1229             yield from pullparser.read_events()
#
# /usr/lib/python3.7/xml/etree/ElementTree.py in feed(self, data)
#    1267         if data:
#    1268             try:
# -> 1269                 self._parser.feed(data)
#    1270             except SyntaxError as exc:
#    1271                 self._events_queue.append(exc)
#
# /usr/lib/python3.7/xml/etree/ElementTree.py in feed(self, data)
#    1628         """Feed encoded data to parser."""
#    1629         try:
# -> 1630             self.parser.Parse(data, 0)
#    1631         except self._error as v:
#    1632             self._raiseerror(v)
#
# ../Modules/pyexpat.c in StartElement()
#
# /usr/lib/python3.7/xml/etree/ElementTree.py in _start(self, tag, attr_list)
#    1550         attrib = {}
#    1551         if attr_list:
# -> 1552             for i in range(0, len(attr_list), 2):
#    1553                 attrib[fixname(attr_list[i])] = attr_list[i+1]
#    1554         return self.target.start(tag, attrib)
#
# KeyboardInterrupt:

# %%
rdf = dict()
rdf = df.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
rdf.head()
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(rdf.Success)

# %% [markdown]
# # dummydata4

# %%
 df2.head()
# Out:
#    Gender_หญิง   Age  ...  Factor_C_Others_0  Factor_C_Others_1
# 0          0.0  42.0  ...                1.0                0.0
# 1          0.0  51.0  ...                1.0                0.0
# 2          1.0  29.0  ...                1.0                0.0
# 3          0.0  58.0  ...                1.0                0.0
# 4          0.0  53.0  ...                1.0                0.0
#
# [5 rows x 177 columns]

# %%
df2.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                     Gender_หญิง       Age  ...  Factor_C_Others_0  Factor_C_Others_1
# Gender_หญิง            1.000000  0.132016  ...           0.088944           0.009051
# Age                    0.132016  1.000000  ...          -0.005322           0.006880
# Province_Happen_11     0.034354  0.002529  ...           0.051603          -0.005605
# Province_Happen_12    -0.020184  0.003032  ...          -0.022996           0.004334
# Province_Happen_13     0.010391  0.001509  ...          -0.011899          -0.004695
# ...                         ...       ...  ...                ...                ...
# Factor_C_Dept_1        0.013404 -0.026763  ...          -0.066821           0.065455
# Factor_C_Mental_0      0.087560 -0.007940  ...           0.983252          -0.020666
# Factor_C_Mental_1     -0.000910 -0.011427  ...          -0.034072           0.157611
# Factor_C_Others_0      0.088944 -0.005322  ...           1.000000           0.082375
# Factor_C_Others_1      0.009051  0.006880  ...           0.082375           1.000000
#
# [177 rows x 177 columns]

# %%
rdf2 = dict()
rdf2= df2.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)
rdf2.head()
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(rdf2.Success)
# Out:
# Gender_หญิง                       0.401420
# Age                               0.081634
# Province_Happen_11                0.051020
# Province_Happen_12               -0.023553
# Province_Happen_13                0.010822
# Province_Happen_14                0.053184
# Province_Happen_15                0.023986
# Province_Happen_16                0.051399
# Province_Happen_17                0.017578
# Province_Happen_18                0.010369
# Province_Happen_19                0.038549
# Province_Happen_20                0.037864
# Province_Happen_21                0.027721
# Province_Happen_22                0.056697
# Province_Happen_23                0.027556
# Province_Happen_24                0.022763
# Province_Happen_25                0.032720
# Province_Happen_26                0.013994
# Province_Happen_27                0.034891
# Province_Happen_30                0.083314
# Province_Happen_31               -0.003666
# Province_Happen_32                0.032167
# Province_Happen_33                0.061521
# Province_Happen_34                0.036587
# Province_Happen_35                0.017676
# Province_Happen_36                0.029930
# Province_Happen_37                0.008626
# Province_Happen_38               -0.006436
# Province_Happen_39                0.001702
# Province_Happen_40                0.049528
# Province_Happen_41               -0.005691
# Province_Happen_42                0.036886
# Province_Happen_43                0.027427
# Province_Happen_44                0.018598
# Province_Happen_45                0.043057
# Province_Happen_46                0.007814
# Province_Happen_47                0.019460
# Province_Happen_48               -0.003453
# Province_Happen_49               -0.019879
# Province_Happen_50                0.018902
# Province_Happen_51               -0.022438
# Province_Happen_52                0.070227
# Province_Happen_53                0.010846
# Province_Happen_54                0.013087
# Province_Happen_55               -0.022679
# Province_Happen_56               -0.030102
# Province_Happen_57                0.031930
# Province_Happen_58                0.018930
# Province_Happen_60                0.057687
# Province_Happen_61                0.020774
# Province_Happen_62                0.028929
# Province_Happen_63                0.022262
# Province_Happen_64                0.009126
# Province_Happen_65                0.017458
# Province_Happen_66                0.000665
# Province_Happen_67                0.021513
# Province_Happen_70                0.036124
# Province_Happen_71                0.020509
# Province_Happen_72                0.064535
# Province_Happen_73                0.067765
# Province_Happen_74                0.045720
# Province_Happen_75                0.021177
# Province_Happen_76                0.040527
# Province_Happen_77                0.018119
# Province_Happen_80               -0.001230
# Province_Happen_81                0.028482
# Province_Happen_82                0.024527
# Province_Happen_83                0.024996
# Province_Happen_84                0.048386
# Province_Happen_85                0.006576
# Province_Happen_86                0.015546
# Province_Happen_90                0.051876
# Province_Happen_91                0.031738
# Province_Happen_92                0.039388
# Province_Happen_93               -0.002595
# Province_Happen_94                0.014695
# Province_Happen_95                0.019659
# Province_Happen_96                0.034175
# Province_Happen_unknown          -0.647743
# Province_Happen_ต่างประเทศ        0.002942
# Status_คู่                       -0.001112
# Status_สมณะ                      -0.032735
# Status_หม้าย                     -0.083916
# Status_หย่า                      -0.096628
# Status_แยก                       -0.014874
# Status_โสด                       -0.117186
# Religion_คริสต์                  -0.010691
# Religion_ซิกข์                    0.002942
# Religion_บาไฮ                     0.002942
# Religion_พุทธ                     0.003699
# Religion_อิสลาม                   0.044770
# Religion_ไม่นับถือศาสนา           0.005879
# WTK_Overdose_1                    0.424775
# WTK_Insecticide_1                 0.071088
# WTK_Herbicide_1                  -0.013619
# WTK_Other_Chemicals_1             0.195935
# WTK_Sharp_Weapons_1               0.170999
# WTK_Guns_1                       -0.169954
# WTK_Jump_Off_Building_1           0.055461
# WTK_Hang_1                        0.668021
# WTK_Jump_Into_Water_1            -0.001318
# WTK_Ran_Into_Cars_1               0.015204
# WTK_Smoke_Gas_1                   0.011931
# Disease_M_Physcopath_1           -0.019122
# Disease_M_Depression_1            0.106591
# Disease_M_Others_1               -0.028745
# Disease_P_Diabetes_1             -0.077188
# Disease_P_HBP_1                  -0.107191
# Disease_P_Cardio_1               -0.040937
# Disease_P_Kidney_1               -0.058533
# Disease_P_Liver_1                -0.038004
# Disease_P_lung_1                 -0.061374
# Disease_P_Migrant_1               0.015959
# Disease_P_Joint_1                -0.070124
# Disease_P_Paralyze_1             -0.068585
# Disease_P_Cancer_1               -0.079517
# Disease_P_HIV_1                  -0.016507
# Disease_P_Others_1                0.037170
# Time_Group_1                     -0.002522
# Time_Group_2                     -0.168309
# Time_Group_3                     -0.049893
# Time_Group_4                     -0.005471
# Time_Group_5                      0.046443
# Time_Group_6                     -0.088367
# Month_Group_1                    -0.013163
# Month_Group_2                    -0.019450
# Month_Group_3                    -0.001173
# Month_Group_4                     0.034373
# Attempt_Year                      0.107445
# Attempt_Hurt_Others_0             0.355221
# Attempt_Hurt_Others_1            -0.011028
# Attempt_Ever_0                    0.147037
# Attempt_Ever_1                    0.162984
# Attempt_To_Die_0                  0.412133
# Attempt_To_Die_1                 -0.344452
# Attempt_Sign_0                    0.322465
# Attempt_Sign_1                    0.140984
# Factor_R_Neglected_1              0.102327
# Factor_R_Humuliated_1             0.021352
# Factor_R_Jeolous_1                0.073126
# Factor_R_Qurrel_1                 0.207010
# Factor_R_Needy_1                  0.050033
# Factor_R_Lost_1                  -0.027750
# Factor_R_Aging_Lonesome_1        -0.088783
# Factor_R_Working_Environment_1    0.028780
# Factor_Alcoholic_0                0.365834
# Factor_Alcoholic_1               -0.132269
# Factor_A_At_Sucide_Attempt_1     -0.088200
# Factor_Drugs_0                    0.377255
# Factor_Drugs_1                   -0.088461
# Factor_D_At_Sucide_Attempt_1     -0.035845
# Factor_Di_Lonesone_0             -0.289385
# Factor_Di_Lonesone_1             -0.053420
# Factor_Di_Pain_0                  0.305145
# Factor_Di_Pain_1                  0.113106
# Factor_Economic_0                 0.306137
# Factor_Economic_1                -0.045851
# Factor_E_Poor_0                   0.304084
# Factor_E_Poor_1                  -0.008639
# Factor_E_Unemployed_0             0.319145
# Factor_E_Unemployed_1            -0.021778
# Factor_E_Dept_0                   0.301191
# Factor_E_Dept_1                   0.001047
# Factor_Others_1                   0.013121
# Success                           1.000000
# Disease_P_Direct_COVID_1          0.003214
# Disease_P_COVID_1                -0.005506
# Factor_C_Unemployed_0             0.314608
# Factor_C_Unemployed_1             0.011329
# Factor_C_Poor_0                   0.317462
# Factor_C_Poor_1                   0.023742
# Factor_C_Dept_0                   0.317344
# Factor_C_Dept_1                   0.023907
# Factor_C_Mental_0                 0.312882
# Factor_C_Mental_1                -0.002427
# Factor_C_Others_0                 0.312823
# Factor_C_Others_1                -0.006002
# Name: Success, dtype: float64

# %% [markdown]
# ##Feature important

# %% [markdown]
# Decision Tree file dummy4

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

df = df2
list_col = list(df.columns)
feature_cols = list(list_col)
feature_cols.remove("Success")
#feature_cols = ['Gender_หญิง', 'Age', 'Province_Happen_11', 'Province_Happen_12', 'Province_Happen_13', 'Province_Happen_14', 'Province_Happen_15', 'Province_Happen_16', 'Province_Happen_17', 'Province_Happen_18', 'Province_Happen_19', 'Province_Happen_20', 'Province_Happen_21', 'Province_Happen_22', 'Province_Happen_23', 'Province_Happen_24', 'Province_Happen_25', 'Province_Happen_26', 'Province_Happen_27', 'Province_Happen_30', 'Province_Happen_31', 'Province_Happen_32', 'Province_Happen_33', 'Province_Happen_34', 'Province_Happen_35', 'Province_Happen_36', 'Province_Happen_37', 'Province_Happen_38', 'Province_Happen_39', 'Province_Happen_40', 'Province_Happen_41', 'Province_Happen_42', 'Province_Happen_43', 'Province_Happen_44', 'Province_Happen_45', 'Province_Happen_46', 'Province_Happen_47', 'Province_Happen_48', 'Province_Happen_49', 'Province_Happen_50', 'Province_Happen_51', 'Province_Happen_52', 'Province_Happen_53', 'Province_Happen_54', 'Province_Happen_55', 'Province_Happen_56', 'Province_Happen_57', 'Province_Happen_58', 'Province_Happen_60', 'Province_Happen_61', 'Province_Happen_62', 'Province_Happen_63', 'Province_Happen_64', 'Province_Happen_65', 'Province_Happen_66', 'Province_Happen_67', 'Province_Happen_70', 'Province_Happen_71', 'Province_Happen_72', 'Province_Happen_73', 'Province_Happen_74', 'Province_Happen_75', 'Province_Happen_76', 'Province_Happen_77', 'Province_Happen_80', 'Province_Happen_81', 'Province_Happen_82', 'Province_Happen_83', 'Province_Happen_84', 'Province_Happen_85', 'Province_Happen_86', 'Province_Happen_90', 'Province_Happen_91', 'Province_Happen_92', 'Province_Happen_93', 'Province_Happen_94', 'Province_Happen_95', 'Province_Happen_96', 'Province_Happen_ต่างประเทศ', 'Status_คู่', 'Status_สมณะ', 'Status_หม้าย', 'Status_หย่า', 'Status_แยก', 'Status_โสด', 'Religion_คริสต์', 'Religion_ซิกข์', 'Religion_บาไฮ', 'Religion_พุทธ', 'Religion_อิสลาม', 'Religion_ไม่นับถือศาสนา', 'Disease_M_Physcopath_1', 'Disease_M_Depression_1', 'Disease_M_Others_1', 'Disease_P_Diabetes_1', 'Disease_P_HBP_1', 'Disease_P_Cardio_1', 'Disease_P_Kidney_1', 'Disease_P_Liver_1', 'Disease_P_lung_1', 'Disease_P_Migrant_1', 'Disease_P_Joint_1', 'Disease_P_Paralyze_1', 'Disease_P_Cancer_1', 'Disease_P_HIV_1', 'Disease_P_Others_1', 'Attempt_Ever_0', 'Attempt_Ever_1', 'Attempt_Sign_0', 'Attempt_Sign_1', 'Factor_R_Neglected_1', 'Factor_R_Humuliated_1', 'Factor_R_Jeolous_1', 'Factor_R_Qurrel_1', 'Factor_R_Needy_1', 'Factor_R_Lost_1', 'Factor_R_Aging_Lonesome_1', 'Factor_R_Working_Environment_1', 'Factor_Alcoholic_0', 'Factor_Alcoholic_1', 'Factor_A_At_Sucide_Attempt_1', 'Factor_Drugs_0', 'Factor_Drugs_1', 'Factor_D_At_Sucide_Attempt_1', 'Factor_Di_Lonesone_0', 'Factor_Di_Lonesone_1', 'Factor_Di_Pain_0', 'Factor_Di_Pain_1', 'Factor_Economic_0', 'Factor_Economic_1', 'Factor_E_Poor_0', 'Factor_E_Poor_1', 'Factor_E_Unemployed_0', 'Factor_E_Unemployed_1', 'Factor_E_Dept_0', 'Factor_E_Dept_1', 'Factor_Others_1', 'Disease_P_Direct_COVID_1', 'Disease_P_COVID_1', 'Factor_C_Unemployed_0', 'Factor_C_Unemployed_1', 'Factor_C_Poor_0', 'Factor_C_Poor_1', 'Factor_C_Dept_0', 'Factor_C_Dept_1', 'Factor_C_Mental_0', 'Factor_C_Mental_1', 'Factor_C_Others_0', 'Factor_C_Others_1']
feature_cols = ['Gender_หญิง', 'Age', 'Status_คู่', 'Status_สมณะ', 'Status_หม้าย', 'Status_หย่า', 'Status_แยก', 'Status_โสด', 'Religion_คริสต์', 'Religion_ซิกข์', 'Religion_บาไฮ', 'Religion_พุทธ', 'Religion_อิสลาม', 'Religion_ไม่นับถือศาสนา', 'Disease_M_Physcopath_1', 'Disease_M_Depression_1', 'Disease_M_Others_1', 'Disease_P_Diabetes_1', 'Disease_P_HBP_1', 'Disease_P_Cardio_1', 'Disease_P_Kidney_1', 'Disease_P_Liver_1', 'Disease_P_lung_1', 'Disease_P_Migrant_1', 'Disease_P_Joint_1', 'Disease_P_Paralyze_1', 'Disease_P_Cancer_1', 'Disease_P_HIV_1', 'Disease_P_Others_1', 'Attempt_Ever_0', 'Attempt_Ever_1', 'Attempt_Sign_0', 'Attempt_Sign_1', 'Factor_R_Neglected_1', 'Factor_R_Humuliated_1', 'Factor_R_Jeolous_1', 'Factor_R_Qurrel_1', 'Factor_R_Needy_1', 'Factor_R_Lost_1', 'Factor_R_Aging_Lonesome_1', 'Factor_R_Working_Environment_1', 'Factor_Alcoholic_0', 'Factor_Alcoholic_1', 'Factor_Drugs_0', 'Factor_Drugs_1', 'Factor_Di_Lonesone_0', 'Factor_Di_Lonesone_1', 'Factor_Di_Pain_0', 'Factor_Di_Pain_1', 'Factor_Economic_0', 'Factor_Economic_1', 'Factor_E_Poor_0', 'Factor_E_Poor_1', 'Factor_E_Unemployed_0', 'Factor_E_Unemployed_1', 'Factor_E_Dept_0', 'Factor_E_Dept_1', 'Factor_Others_1', 'Disease_P_Direct_COVID_1', 'Disease_P_COVID_1', 'Factor_C_Unemployed_0', 'Factor_C_Unemployed_1', 'Factor_C_Poor_0', 'Factor_C_Poor_1', 'Factor_C_Dept_0', 'Factor_C_Dept_1', 'Factor_C_Mental_0', 'Factor_C_Mental_1', 'Factor_C_Others_0', 'Factor_C_Others_1']


X = df[feature_cols] # Features
y = df.Success # Target variable

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.789639458517625

# %%
# decision tree for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot
# define dataset
#X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
X = df[feature_cols] # Features
y = df.Success # Target variable

# define the model
model = DecisionTreeClassifier()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print(feature_cols[i]+' %0d   Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Gender_หญิง 0   Score: 0.16749
# Age 1   Score: 0.18731
# Status_คู่ 2   Score: 0.01406
# Status_สมณะ 3   Score: 0.00068
# Status_หม้าย 4   Score: 0.00577
# Status_หย่า 5   Score: 0.00699
# Status_แยก 6   Score: 0.00440
# Status_โสด 7   Score: 0.01375
# Religion_คริสต์ 8   Score: 0.00200
# Religion_ซิกข์ 9   Score: 0.00000
# Religion_บาไฮ 10   Score: 0.00000
# Religion_พุทธ 11   Score: 0.00576
# Religion_อิสลาม 12   Score: 0.00233
# Religion_ไม่นับถือศาสนา 13   Score: 0.00018
# Disease_M_Physcopath_1 14   Score: 0.01406
# Disease_M_Depression_1 15   Score: 0.01362
# Disease_M_Others_1 16   Score: 0.00794
# Disease_P_Diabetes_1 17   Score: 0.00743
# Disease_P_HBP_1 18   Score: 0.01006
# Disease_P_Cardio_1 19   Score: 0.00265
# Disease_P_Kidney_1 20   Score: 0.00188
# Disease_P_Liver_1 21   Score: 0.00118
# Disease_P_lung_1 22   Score: 0.00261
# Disease_P_Migrant_1 23   Score: 0.00104
# Disease_P_Joint_1 24   Score: 0.00306
# Disease_P_Paralyze_1 25   Score: 0.00428
# Disease_P_Cancer_1 26   Score: 0.00235
# Disease_P_HIV_1 27   Score: 0.00348
# Disease_P_Others_1 28   Score: 0.00971
# Attempt_Ever_0 29   Score: 0.01845
# Attempt_Ever_1 30   Score: 0.01266
# Attempt_Sign_0 31   Score: 0.05846
# Attempt_Sign_1 32   Score: 0.00946
# Factor_R_Neglected_1 33   Score: 0.02286
# Factor_R_Humuliated_1 34   Score: 0.00302
# Factor_R_Jeolous_1 35   Score: 0.01577
# Factor_R_Qurrel_1 36   Score: 0.01931
# Factor_R_Needy_1 37   Score: 0.01037
# Factor_R_Lost_1 38   Score: 0.00377
# Factor_R_Aging_Lonesome_1 39   Score: 0.00282
# Factor_R_Working_Environment_1 40   Score: 0.00406
# Factor_Alcoholic_0 41   Score: 0.01560
# Factor_Alcoholic_1 42   Score: 0.01537
# Factor_Drugs_0 43   Score: 0.03813
# Factor_Drugs_1 44   Score: 0.00676
# Factor_Di_Lonesone_0 45   Score: 0.00892
# Factor_Di_Lonesone_1 46   Score: 0.00484
# Factor_Di_Pain_0 47   Score: 0.01347
# Factor_Di_Pain_1 48   Score: 0.00666
# Factor_Economic_0 49   Score: 0.02088
# Factor_Economic_1 50   Score: 0.00685
# Factor_E_Poor_0 51   Score: 0.00521
# Factor_E_Poor_1 52   Score: 0.00349
# Factor_E_Unemployed_0 53   Score: 0.00442
# Factor_E_Unemployed_1 54   Score: 0.00388
# Factor_E_Dept_0 55   Score: 0.02213
# Factor_E_Dept_1 56   Score: 0.00402
# Factor_Others_1 57   Score: 0.01877
# Disease_P_Direct_COVID_1 58   Score: 0.00000
# Disease_P_COVID_1 59   Score: 0.00000
# Factor_C_Unemployed_0 60   Score: 0.00133
# Factor_C_Unemployed_1 61   Score: 0.00120
# Factor_C_Poor_0 62   Score: 0.01330
# Factor_C_Poor_1 63   Score: 0.00116
# Factor_C_Dept_0 64   Score: 0.10249
# Factor_C_Dept_1 65   Score: 0.00048
# Factor_C_Mental_0 66   Score: 0.00095
# Factor_C_Mental_1 67   Score: 0.00082
# Factor_C_Others_0 68   Score: 0.00111
# Factor_C_Others_1 69   Score: 0.00064

# %%
# logistic regression for feature importance
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
# define dataset
#X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# define the model
model = LogisticRegression()
# fit the model
model.fit(X, y)
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
  print(feature_cols[i]+' %0d   Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Age 0   Score: 0.03035
# หญิง 1   Score: -1.06311
# Province_Happen_11 2   Score: -0.05878
# Province_Happen_12 3   Score: -0.02681
# Province_Happen_13 4   Score: -0.02387
# Province_Happen_14 5   Score: -0.05618
# Province_Happen_15 6   Score: -0.03268
# Province_Happen_16 7   Score: -0.11169
# Province_Happen_17 8   Score: -0.02343
# Province_Happen_18 9   Score: -0.01857
# Province_Happen_19 10   Score: -0.04548
# Province_Happen_20 11   Score: -0.08093
# Province_Happen_21 12   Score: -0.05105
# Province_Happen_22 13   Score: -0.10943
# Province_Happen_23 14   Score: -0.02889
# Province_Happen_24 15   Score: -0.03382
# Province_Happen_25 16   Score: -0.05299
# Province_Happen_26 17   Score: -0.01573
# Province_Happen_27 18   Score: -0.04880
# Province_Happen_30 19   Score: -0.28084
# Province_Happen_31 20   Score: -0.03869
# Province_Happen_32 21   Score: -0.09749
# Province_Happen_33 22   Score: -0.15212
# Province_Happen_34 23   Score: -0.06386
# Province_Happen_35 24   Score: -0.03541
# Province_Happen_36 25   Score: -0.06789
# Province_Happen_37 26   Score: -0.01567
# Province_Happen_38 27   Score: -0.00594
# Province_Happen_39 28   Score: -0.01091
# Province_Happen_40 29   Score: -0.15102
# Province_Happen_41 30   Score: -0.01066
# Province_Happen_42 31   Score: -0.08421
# Province_Happen_43 32   Score: -0.02504
# Province_Happen_44 33   Score: -0.03928
# Province_Happen_45 34   Score: -0.08768
# Province_Happen_46 35   Score: -0.04363
# Province_Happen_47 36   Score: -0.05089
# Province_Happen_48 37   Score: -0.02910
# Province_Happen_49 38   Score: -0.00031
# Province_Happen_50 39   Score: -0.15034
# Province_Happen_51 40   Score: -0.02158
# Province_Happen_52 41   Score: -0.15572
# Province_Happen_53 42   Score: -0.04506
# Province_Happen_54 43   Score: -0.06352
# Province_Happen_55 44   Score: -0.02493
# Province_Happen_56 45   Score: -0.00386
# Province_Happen_57 46   Score: -0.15208
# Province_Happen_58 47   Score: -0.04421
# Province_Happen_60 48   Score: -0.13600
# Province_Happen_61 49   Score: -0.03051
# Province_Happen_62 50   Score: -0.05758
# Province_Happen_63 51   Score: -0.04411
# Province_Happen_64 52   Score: -0.04198
# Province_Happen_65 53   Score: -0.06691
# Province_Happen_66 54   Score: -0.01886
# Province_Happen_67 55   Score: -0.07788
# Province_Happen_70 56   Score: -0.05561
# Province_Happen_71 57   Score: -0.04299
# Province_Happen_72 58   Score: -0.12141
# Province_Happen_73 59   Score: -0.09733
# Province_Happen_74 60   Score: -0.07805
# Province_Happen_75 61   Score: -0.01366
# Province_Happen_76 62   Score: -0.04600
# Province_Happen_77 63   Score: -0.03543
# Province_Happen_80 64   Score: -0.05379
# Province_Happen_81 65   Score: -0.03583
# Province_Happen_82 66   Score: -0.02631
# Province_Happen_83 67   Score: -0.02367
# Province_Happen_84 68   Score: -0.08923
# Province_Happen_85 69   Score: -0.00948
# Province_Happen_86 70   Score: -0.03073
# Province_Happen_90 71   Score: -0.10786
# Province_Happen_91 72   Score: -0.02778
# Province_Happen_92 73   Score: -0.10589
# Province_Happen_93 74   Score: -0.01968
# Province_Happen_94 75   Score: -0.01035
# Province_Happen_95 76   Score: -0.00824
# Province_Happen_96 77   Score: -0.02811
# Province_Happen_ต่างประเทศ 78   Score: -0.00010
# Status_สมณะ 79   Score: 0.01772
# Status_หม้าย 80   Score: 0.03461
# Status_หย่า 81   Score: 0.17893
# Status_แยก 82   Score: 0.05549
# Status_โสด 83   Score: 0.12657
# Status_ไม่ทราบ 84   Score: 0.02745
# Religion_ซิกข์ 85   Score: -0.00019
# Religion_บาไฮ 86   Score: -0.00006
# Religion_พุทธ 87   Score: 0.02669
# Religion_อิสลาม 88   Score: -0.05219
# Religion_ไม่ทราบ 89   Score: 0.03459
# Religion_ไม่นับถือศาสนา 90   Score: -0.00087
# Religion_ไม่ระบุ 91   Score: -0.03409
# WTK_Overdose 92   Score: -1.39088
# WTK_Insecticide 93   Score: -0.34303
# WTK_Herbicide 94   Score: 0.03696
# WTK_Other_Chemicals 95   Score: -0.61746
# WTK_Sharp_Weapons 96   Score: -0.43111
# WTK_Guns 97   Score: 0.33169
# WTK_Jump_Off_Building 98   Score: -0.17727
# WTK_Hang 99   Score: 2.59365
# WTK_Jump_Into_Water 100   Score: 0.01896
# WTK_Ran_Into_Cars 101   Score: -0.00650
# WTK_Smoke_Gas 102   Score: 0.00738
# Disease_M_Physcopath 103   Score: -0.00981
# Disease_M_Depression 104   Score: -0.17422
# Disease_M_Others 105   Score: 0.04114
# Disease_P_Diabetes 106   Score: 0.00022
# Disease_P_HBP 107   Score: -0.07360
# Disease_P_Cardio 108   Score: -0.00960
# Disease_P_Kidney 109   Score: 0.01236
# Disease_P_Liver 110   Score: 0.01285
# Disease_P_lung 111   Score: 0.00407
# Disease_P_Migrant 112   Score: -0.01156
# Disease_P_Joint 113   Score: 0.01634
# Disease_P_Paralyze 114   Score: 0.00537
# Disease_P_Cancer 115   Score: 0.05215
# Disease_P_HIV 116   Score: 0.00496
# Disease_P_Others 117   Score: -0.00490
# Attempt_Date 118   Score: -0.00341
# Attempt_Month 119   Score: -0.06977
# Attempt_Year 120   Score: -0.00153
# Attempt_Hurt_Others_1 121   Score: 0.01225
# Attempt_Hurt_Others_ไม่ทราบ 122   Score: 0.49407
# Attempt_Ever_1 123   Score: -0.37237
# Attempt_Ever_ไม่ทราบ 124   Score: 0.69462
# Attempt_To_Die_1 125   Score: 1.43276
# Attempt_To_Die_ไม่ทราบ 126   Score: 0.05031
# Attempt_Sign_1 127   Score: 0.54756
# Attempt_Sign_ไม่ทราบ 128   Score: 0.28151
# Factor_R_Neglected 129   Score: -0.15806
# Factor_R_Humuliated 130   Score: -0.01894
# Factor_R_Jeolous 131   Score: -0.04940
# Factor_R_Qurrel 132   Score: -0.48927
# Factor_R_Needy 133   Score: -0.04412
# Factor_R_Lost 134   Score: 0.01317
# Factor_R_Aging_Lonesome 135   Score: 0.00279
# Factor_R_Working_Environment 136   Score: -0.02468
# Factor_Alcoholic_1 137   Score: 0.15292
# Factor_Alcoholic_ไม่ทราบ 138   Score: 0.31482
# Factor_A_At_Sucide_Attempt 139   Score: 0.05742
# Factor_Drugs_1 140   Score: 0.24919
# Factor_Drugs_ไม่ทราบ 141   Score: 0.37903
# Factor_D_At_Sucide_Attempt 142   Score: 0.08377
# Factor_Di_Lonesone 143   Score: 0.03067
# Factor_Di_Pain 144   Score: 0.18646
# Factor_Economic_1 145   Score: 0.21089
# Factor_Economic_ไม่ทราบ 146   Score: 0.37111
# Factor_E_Poor 147   Score: -0.04736
# Factor_E_Unemployed 148   Score: 0.06718
# Factor_E_Dept 149   Score: 0.12664
# Factor_Others 150   Score: 0.05137
# Disease_P_Direct_COVID_1 151   Score: -0.00028
# Disease_P_Direct_COVID_ไม่ทราบ 152   Score: 1.45028
# Disease_P_COVID_1 153   Score: -0.00046
# Disease_P_COVID_ไม่ทราบ 154   Score: 1.45028
# Factor_C_Unemployed_1 155   Score: 0.00901
# Factor_C_Unemployed_ไม่ทราบ 156   Score: 1.45028
# Factor_C_Poor_1 157   Score: -0.00441
# Factor_C_Poor_ไม่ทราบ 158   Score: 1.45028
# Factor_C_Dept_1 159   Score: -0.01848
# Factor_C_Dept_ไม่ทราบ 160   Score: 1.45028
# Factor_C_Mental_1 161   Score: 0.00914
# Factor_C_Mental_ไม่ทราบ 162   Score: 1.45028
# Factor_C_Others_1 163   Score: 0.01809
# Factor_C_Others_ไม่ทราบ 164   Score: 1.45028
