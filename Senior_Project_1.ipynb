# %% [markdown]
# # Data Manipulation (Suicide_Attempt)

# %%
from google.colab import drive   ##Import Essential Package
import pandas as pd

drive.mount('/content/drive') ##Get Permission fron google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
xls_Suicide_Attempt = pd.ExcelFile("/content/drive/MyDrive/ตาย ไม่ตาย 2561-2564/ไม่ตาย 61-64.xlsx")
SA_SheetNames = xls_Suicide_Attempt.sheet_names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-cf0bf5726b64> in <module>()
# ----> 1 xls_Suicide_Attempt = pd.ExcelFile("/content/drive/MyDrive/ตาย ไม่ตาย 2561-2564/ไม่ตาย 61-64.xlsx")
#       2 SA_SheetNames = xls_Suicide_Attempt.sheet_names
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ...

# %%
New_Column_Names = ['Order_ID','Where_Record','Province_Where_Recode','Gender','Age','Province_Happen','Same_As_Census','Province_Census','Status','Religion','Jobs', ##New Columns Names
                     
                     'WTK_Overdose','WTK_Insecticide','WTK_Herbicide','WTK_Other_Chemicals','WTK_What_Chemicals',
                     'WTK_Sharp_Weapons','WTK_Guns','WTK_Jump_Off_Building','WTK_Hang','WTK_Jump_Into_Water','WTK_Ran_Into_Cars','WTK_Smoke_Gas','WTK_Others',

                     'Disease_Conginential',
                     
                     'Disease_Mental','Disease_M_Physcopath','Disease_M_Depression','Disease_M_Others','Disease_M_What',

                     'Disease_Physical','Disease_P_Diabetes','Disease_P_HBP','Disease_P_Cardio','Disease_P_Kidney','Disease_P_Liver','Disease_P_lung',
                     'Disease_P_Migrant','Disease_P_Joint','Disease_P_Paralyze','Disease_P_Cancer','Disease_P_HIV','Disease_P_Others','Disease_P_What',
                     'Disease_P_Direct_COVID','Disease_P_COVID',

                     'Attempt_Date','Attempt_Month','Attempt_Year','Attemp_Time',

                     'Attempt_Hurt_Others','Attempt_Hurt_Others_Who','Attempt_Ever','Attemp_Ever_Month','Attempt_Ever_Year','Attempt_To_Die','Attempt_Sign','Attempt_Sign_What','Attempt_Ever_Last_Date','Attempt_Ever_Lasr_Month'

                     'Factor_R_Neglected','Factor_R_Humuliated','Factor_R_Jeolous','Factor_R_Qurrel','Factor_R_Needy','Factor_R_Lost','Factor_R_Aging','Factor_R_Working_Environment','Factor_R_Lonesome',

                     'Factor_Alcoholic','Factor_A_Rate','Factor_A_At_Sucide_Attempt',

                     'Factor_Drugs','Factor_D_Rate','Factor_D_At_Sucide_Attempt',

                     'Factor_Disease','Factor_Di_Lonesone','Factor_Di_Pain',

                     'Factor_Economic','Factor_E_Poor','Factor_E_Unemployed','Factor_E_Dept',

                     'Factor_Others','Factor_Other_What',

                     'Factor_COVID', 'Factor_C_Unemployed', 'Factor_C_Poor', 'Factor_C_Dept', 'Factor_C_Mental','Factor_C_Others','Factor_C_Other_What',

                     'Service_Treatment','Service_T_Pill_AntiDepressed','Service_T_Pill_AntiAnxiety','Service_T_Elect','Service_T_Quarantine','Service_T_Pill_COVID',

                     'Service_Mental','Service_M_First_Aid','Service_M_Consult','Service_M_Group',
                     
                     'Service_Others','Service_Other_What',

                     'Service_Admit',

                     'Assessment_Depressed',

                     'Assessment_Suicide_Attempt'

]

# %%
x = pd.DataFrame(New_Column_Names,list(old.columns))
x.to_excel("x.xlsx")

# %%
print(len(New_Column_Names))
# Out:
# 105

# %%
df = dict() ##Create Dict to Collect Each Sheet from Suicide_Attemp
for sheetnames in SA_SheetNames[:-1]:
  df[sheetnames] = pd.read_excel(xls_Suicide_Attempt,sheetnames, header = None, names=New_Column_Names)
  print(len(list(df[sheetnames].columns)))
  df[sheetnames]['Year'] = sheetnames ##Create Now Cols from its Year
  df[sheetnames]['Success'] = 0
  df[sheetnames] = df[sheetnames].drop(0)
# Out:
# 105
# 105
# 105
# 105

# %%
Concated_Suicide_Attempt = pd.concat(df, ignore_index = True)

# %%
Concated_Suicide_Attempt
# Out:
#           Where_Record Province_Where_Recode  ...  Year Success
# 0       โรงพยาบาลชุมชน               สระบุรี  ...  2561       0
# 1       โรงพยาบาลชุมชน               สระบุรี  ...  2561       0
# 2       โรงพยาบาลชุมชน             บุรีรัมย์  ...  2561       0
# 3       โรงพยาบาลชุมชน               สระบุรี  ...  2561       0
# 4       โรงพยาบาลชุมชน               สระบุรี  ...  2561       0
# ...                ...                   ...  ...   ...     ...
# 34769   โรงพยาบาลชุมชน               ปัตตานี  ...  2564       0
# 34770   โรงพยาบาลชุมชน             เพชรบูรณ์  ...  2564       0
# 34771   โรงพยาบาลชุมชน               ชัยภูมิ  ...  2564       0
# 34772   โรงพยาบาลชุมชน               ชัยภูมิ  ...  2564       0
# 34773  โรงพยาบาลทั่วไป       พระนครศรีอยุธยา  ...  2564       0
#
# [34774 rows x 106 columns]

# %% [markdown]
# # Data Manipulation (Suicide)

# %%
xls_Suicide = pd.ExcelFile("/content/drive/MyDrive/ตาย ไม่ตาย 2561-2564/ตายสำเร็จ61-64.xlsx")
S_SheetNames = xls_Suicide.sheet_names

# %%
df_s = dict()
for sheetnames in S_SheetNames:
  df_s[sheetnames] = pd.read_excel(xls_Suicide,sheetnames)

# %%
df_s
# Out:
# {'2561':         No  A1        Ch            Am  ...   C25_2   C25_3    C26   C26_text
#  0        1   1        12          1206  ...       0       0      0        NaN
#  1        2   3        12          1201  ...       0       0      0        NaN
#  2        3   2        12          1206  ...       0       0      0        NaN
#  3        4   1        12          1202  ...       0       0      0        NaN
#  4        5   3        12          1201  ...       1       0      1  มีหนี้สิน
#  ...    ...  ..       ...           ...  ...     ...     ...    ...        ...
#  3561  3562   1  จันทบุรี        สอยดาว  ...  ไม่ใช่  ไม่ใช่  ไม่มี        NaN
#  3562  3563   2       ตาก       อุ้มผาง  ...  ไม่ใช่  ไม่ใช่  ไม่มี        NaN
#  3563  3564   3     พังงา    เมืองพังงา  ...  ไม่ใช่  ไม่ใช่  ไม่มี        NaN
#  3564  3565   5   นนทบุรี  เมืองนนทบุรี  ...  ไม่ใช่  ไม่ใช่  ไม่มี        NaN
#  3565  3566   3     พังงา    เมืองพังงา  ...  ไม่ใช่     ใช่  ไม่มี        NaN
#
# ...

# %%
import numpy as np
Column_S = df_s['Sheet1']
len(list(Column_S['นิยาม'][Column_S['นิยาม'].notnull() ]))
# Out:
# 89

# %%
x = pd.DataFrame(list(df_s['2562'].columns))
x.to_excel("y.xlsx")

# %%
old = pd.read_excel(xls_Suicide_Attempt,'2561')
old.columns
# Out:
# Index(['ลำดับ', 'สถานบริการที่รายงาน', 'ชื่อจังหวัด สถานบริการ (prov1)', 'เพศ',
#        'อายุ', 'จังหวัด', 'บ้านเดียวกับทะเบียนบ้าน', 'A72 จังหวัด',
#        'A8.สถานภาพ', 'A9.ศาสนา',
#        ...
#        'D1 ยารักษาโรคโควิด-19', 'D1 บริการที่ได้รับ สังคมจิตใจ',
#        'D1 สุขภาพจิตศึกษา', 'D1 ให้คำปรึกษา', 'D1 กลุ่มบำบัด',
#        'D1 บริการที่ได้รับ อื่น ๆ', 'D1 บริการที่ได้รับ อื่น ๆ ระบุ',
#        'D1 มีการ Admit', 'D2 ผลการประเมินความรุนแรงของโรคซึมเศร้า 9Q',
#        'D3 ผลการประเมินความรุนแรงของโรคซึมเศร้า 8Q'],
#       dtype='object', length=105)

# %%
Column_S[['ชื่อตาราง','นิยาม']][Column_S['นิยาม'].notnull() ].to_excel("z.xlsx")
